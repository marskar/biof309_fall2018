# %% [markdown]
# # Operators and Conditional Statements
# ### October 18th, 2018
# ### Jinping Liu and Michael Chambers
# ---
# ### Outline
# * Jupyter Notebooks/Jupyter Lab
# * Functions Review
# * Operators (followed by exercise)
# * Conditional Statements (followed by exercise)
# * Final Exercise: Making a Magic 8-Ball function
#
# ### Resources
# * [Quick starting guide to Jupyter Notebooks](https://www.youtube.com/watch?v=DPi6CAkUUPY)
# * [Top 5 Magic Commands for Jupyter Notebooks](https://towardsdatascience.com/the-top-5-magic-commands-for-jupyter-notebooks-2bf0c5ae4bb8)
# * [Write Better Python Functions - Jeff Knupp](https://jeffknupp.com/blog/2018/10/11/write-better-python-functions//)
# * [Understanding Boolean Logic in Python 3](https://www.digitalocean.com/community/tutorials/understanding-boolean-logic-in-python-3)

# %% [markdown]
# # Jupyter Notebooks
# ---
# * Incredible resource and tool for data science
# * Offers a reproducible environment that tells a story
# * It's also a great sandbox environment to learn Python
#
# print('this is not a coding cell')
#
# print('this is a coding cell')
#
# # run a code cell
# 2 + 2
#
# # we can create a variable called "x"
# x = 2 + 2
#
# # that variable refers to the value set it to
# x
#
# print(x)
#
# type(x)

# %%
# run code cells out of order
x = 'two'
print(x)
# Out:
# two

# %%
# helpful Jupyter magic commands
print?

# %%
# use shift + tab to see arguments required for function
type()

# %%
# run an infinite function and kill the kernel
while True:
    print('Two infinity...')
# Out:
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# Two infinity...
# ...

# %% [markdown]
# # Functions Review
# ---
# * Why do we need functions?
# * Functions provided by Python upfront
# * Key features to writing good functions:
#     * Sensible name
#     * Documentation
#     * Does one thing
#     * Returns a value
#     * Readability counts!

# %%
# write a simple function with documentation
# this function can be copied into a python script and imported as part of a module
def awesome(x):
    """My awesome little function
    
    Args:
        x (str): string to be delcaired as "awesome"
    
    Returns:
        str: string that awesome-ifies the input
    
    Todo:
        * check that the first letter of the input (x) is capitalized (output in sentence format)
    """
    return f"{x} is AWESOME!"

# %%
awesome("Cheese")
# Out:
# 'Cheese is AWESOME!'

# %% [markdown]
# # Operators (Jinping)
# ---
# ### Introduction
# The Boolean data type can be one of two values, either True or False. We use Booleans in programming to make comparisons and to control the flow of the program.
# Booleans represent the truth values that are associated with the logic branch of mathematics, which informs algorithms in computer science. Named for the mathematician George Boole, the word Boolean always begins with a capitalized B. The values True and False will also always be with a capital T and F respectively, as they are special values in Python.
# In this tutorial, we’ll go over the basics you’ll need to understand how Booleans work, including Boolean comparison and logical operators, and truth tables.

# %% [markdown]
# ### Comparison Operators
# In programming, comparison operators are used to compare values and evaluate down to a single Boolean value of either True or False.
#
# The table below shows Boolean comparison operators.
#
# | **Operator** | **What it means** |
# | --- | --- |
# | == | Equal to |
# | != | Not equal to |
# | \&lt; | Less than |
# | \&gt; | Greater than |
# | \&lt;= | Less than or equal to |
# | \&gt;= | Greater than or equal to |
#
# To understand how these operators work, let&#39;s assign two integers to two variables in a Python program:

# %%
x = 5
y = 8

# %% [markdown]
# We know that in this example, since x has the value of 5, it is less than y which has the value of 8.
#
# Using those two variables and their associated values, let’s go through the operators from the table above. In our program, we’ll ask Python to print out whether each comparison operator evaluates to either True or False. To help us and other humans better understand this output, we’ll have Python also print a string to show us what it’s evaluating.

# %%
x = 5
y = 8

print("x == y:", x == y)
print("x != y:", x != y)
print("x < y:", x < y)
print("x > y:", x > y)
print("x <= y:", x <= y)
print("x >= y:", x >= y)

# %% [markdown]
# Following mathematical logic, in each of the expressions above, Python has evaluated:
#
# - Is 5 (x) equal to 8 (y)?  **False**
# - Is 5 not equal to 8?  **True**
# - Is 5 less than 8?  **True**
# - Is 5 greater than 8?  **False**
# - Is 5 less than or equal to 8?  **True**
# - Is 5 not less than or equal to 8?  **False**
#
# Although we used integers here, we could substitute them with float values.
#
# Strings can also be used with Boolean operators. They are case-sensitive unless you employ an additional [string method](https://www.digitalocean.com/community/tutorials/an-introduction-to-string-functions-in-python-3#making-strings-upper-and-lower-case).
#
# We can look at how strings are compared in practice:

# %%
Sammy = "Sammy"
sammy = "sammy"

print("Sammy == sammy: ", Sammy == sammy)

# %% [markdown]
# The string "Sammy" above is not equal to the string "sammy", because they are not exactly the same; one starts with an upper-case S and the other with a lower-case s. But, if we add another variable that is assigned the value of "Sammy", then they will evaluate to equal:

# %%
Sammy = "Sammy"
sammy = "sammy"
also_Sammy = "Sammy"

print("Sammy == sammy: ", Sammy == sammy)
print("Sammy == also_Sammy", Sammy == also_Sammy)

# %% [markdown]
# You can also use the other comparison operators including > and < to compare two strings. Python will compare these strings lexicographically using the ASCII values of the characters.
#
# We can also evaluate Boolean values with comparison operators:

# %%
t = True
f = False

print("t != f: ", t != f)
# Out:
# t != f:  True

# %% [markdown]
# The above code block evaluated that True is not equal to False.
#
# Note the difference between the two operators = and ==.

# %%
x = y   # Sets x equal to y
x == y  # Evaluates whether x is equal to y

# %% [markdown]
# The first, = is the assignment operator, which will set one value equal to another. The second, == is a comparison operator which will evaluate whether two values are equal.

# %% [markdown]
# ### Logical Operators
#
# There are three logical operators that are used to compare values. They evaluate expressions down to Boolean values, returning either True or False. These operators are and, or, and not and are defined in the table below.
#
# | **Operator** | **What it means** | **What it looks like** |
# | --- | --- | --- |
# | and | True if both are true | x and y |
# | or | True if at least one is true | x or y |
# | not | True only if false | not x |
#
# Logical operators are typically used to evaluate whether two or more expressions are true or not true. For example, they can be used to determine if the grade is passing and that the student is registered in the course, and if both cases are true then the student will be assigned a grade in the system. Another example would be to determine whether a user is a valid active customer of an online shop based on whether they have store credit or have made a purchase in the past 6 months.
#
# To understand how logical operators work, let’s evaluate three expressions:

# %%
print((9 > 7) and (2 < 4))  # Both original expressions are True
print((8 == 8) or (6 != 6)) # One original expression is True
print(not(3 <= 1))          # The original expression is False
# Out:
# True
# True
# True

# %% [markdown]
# In the first case, print((9 > 7) and (2 < 4)), both 9 > 7 and 2 < 4 needed to evaluate to True since the and operator was being used.
#
# In the second case, print((8 == 8) or (6 != 6)), since 8 == 8 evaluated to True, it did not make a difference that 6 != 6 evaluates to False because the or operator was used. If we had used the and operator, this would evaluate to False.
#
# In the third case, print(not(3 <= 1)), the not operator negates the False value that 3 <=1 returns.
#
# Let’s substitute floats for integers and aim for False evaluations:

# %%
print((-0.2 > 1.4) and (0.8 < 3.1)) # One original expression is False
print((7.5 == 8.9) or (9.2 != 9.2)) # Both original expressions are False       
print(not(-5.7 <= 0.3))             # The original expression is True

# %% [markdown]
# In the example above,
#
# - and must have at least one False expression evaluate to False,
# - r must have both expressions evaluate to False,
# - not must have its inner expression be True for the new expression to evaluate to False.
#
# If the results above seem unclear to you, we&#39;ll go through some [truth tables](https://www.digitalocean.com/community/tutorials/understanding-boolean-logic-in-python-3#truth-tables) below to get you up to speed.
#
# You can also write compound statements using and, or, and not:

# %%
not((-0.2 > 1.4) and ((0.8 < 3.1) or (0.1 == 0.1)))
# Out:
# True

# %% [markdown]
# Let’s look at the inner-most expression first: (0.8 < 3.1) or (0.1 == 0.1). This expression evaluates to True because both mathematical statements are True.
#
# Now, we can take the returned value True and combine it with the next inner expression: (-0.2 > 1.4) and (True). This example returns False because the mathematical statement -0.2 > 1.4 is False, and (False) and (True) returns False.
#
# Finally, we have the outer expression: not(False), which evaluates to True, so the final returned value if we print this statement out is **True**
#
# The logical operators and, or, and not evaluate expressions and return Boolean values.

# %% [markdown]
# ### Truth Tables
#
# There is a lot to learn about the logic branch of mathematics, but we can selectively learn some of it to improve our algorithmic thinking when programming.
#
# Below are truth tables for the comparison operator ==, and each of the logic operators and, or, and not. While you may be able to reason them out, it can also be helpful to work to memorize them as that can make your programming decision-making process quicker.
#
# #### **== Truth Table**
#
# | **x** | **==** | **y** | **Returns** |
# | --- | --- | --- | --- |
# | True | == | True | True |
# | True | == | False | False |
# | False | == | True | False |
# | False | == | False | True |
#
# #### **AND Truth Table**
#
# | **x** | **and** | **y** | **Returns** |
# | --- | --- | --- | --- |
# | True | and | True | True |
# | True | and | False | False |
# | False | and | True | False |
# | False | and | False | False |
#
# #### **OR Truth Table**
#
# | **x** | **or** | **y** | **Returns** |
# | --- | --- | --- | --- |
# | True | or | True | True |
# | True | or | False | True |
# | False | or | True | True |
# | False | or | False | False |
#
# #### **NOT Truth Table**
#
# | **not** | **x** | **Returns** |
# | --- | --- | --- |
# | not | True | False |
# | not | False | True |
#
# Truth tables are common mathematical tables used in logic, and are useful to memorize or keep in mind when constructing algorithms (instructions) in computer programming.

# %% [markdown]
# ### Operators Summary
#
# We introduced operators that compair and control the boolean data type.
#
# Note that [arithmetic operators](https://www.programiz.com/python-programming/operators) also exist.  Rather than reducing a value down to True or False, they alter integer and float value types and can be used to perform mathematical operations.

# %%
# example using arithmetic operators
print(2 + 2)

print(2 - 2)

print(5 * 2)

print(5 / 2)

print(5 // 2)

print(5 % 2)
# Out:
# 4
# 0
# 10
# 2.5
# 2
# 1

# %% [markdown]
# ### Quick Exercise
#
# Write out four statements using different operators and data types

# %%
# 1. write an operation using an integer that returns "True"
# eg. 2 < 4

# %%
# 2. write an operation using an integer that returns "False"

# %%
# 3. write an operation using a string that returns "True"
# eg. 'cheese' != 'CHEESE'

# %%
# 4. write an operation using a string that returns "False"
# Out:
# True

# %%
# BONUS: write an operation that converts a string type to an integer and returns "True"

# %% [markdown]
# # Conditional Statements (Michael)
# ---
# Conditional statements are used in code to do different things based the condition of a variable.  This allows you to do different things based on different input.  Conditional statements are tested once and they run in the order that they are written.
#
# Types of conditional statements:
# - **"if"** - use to check if a condition is true, then runs indented block of code
# - **"elif"** - must follow an "if" statement, if the above "if" statement is false, the "elif" statement will be checked
# - **"else"** - must follow an "if" or "elif" statement, used as a catch-all if none of the above statements are found to be true
#
# Constructing a conditional statement:
# - start with one of the three condition types (if, elif, else)
# - for "if" and "elif", write a statement using operators that checks the condition of a variable
# - the first line of a conditional statement ends in a colon (":")
# - the action for the condition is indented (4 spaces)
#     - i.e. indented code runs when the condition is found to be true

# %%
# write a conditional statement that is True
if True:
    print('The condition is True!')

# %%
# now add an "else" statement as a catch-all for when the 
# above condition is not found to be true
x = False

if x:
    print('The condition is True!')
else:
    print('Oh dear, the condition is not True')

# %% [markdown]
# ### You can use operators in your conditional statements to check the condition of a variable

# %%
# create a variable called "water_temperature" and assign a value
water_temperature = -1

# %%
# use a conditional statement to determine if water is boiling
if water_temperature > 100:
    print('Boiling!')

# %%
# use two conditional statements to determine if water is boiling or not
if water_temperature > 100:
    print('Boiling!')
else:
    print('Not boiling!')

# %%
# change variable value to -5
# use three conditional statements to determine that physical state of water
water_temperature = -5
if water_temperature > 100:
    print('Boiling!')
elif water_temperature > 0:
    print('Liquid!')
else:
    print('Solid!')

# %% [markdown]
# ### You can break-up conditional statements to recheck a variable
# Remember, if a variable should changes after it has been checked Python does not "go back" to check it's condition.  This is because the code is executed linearly.

# %%
# set variable "a" equal to 1
a = 1

# check if "a" equals 1
if a == 1:
    print("Variable is equal to 1!")
else:
    print("Whoa man, that variable does NOT equal 1.")

# change the value of variable "a"
a += 1

# check again if "a" equals 1
if a == 1:
    print("Variable is equal to 1!")
else:
    print("Whoa man, that variable does NOT equal 1.")
# Out:
# a=1!
# Whoa man, that variable does NOT equal 1.

# %% [markdown]
# ### What's the difference between using "if" and "elif"?
# You could certainly use "if" multiple times and **all** the conditions will be tested.

# %%
a = 1
b = 2
c = 3
greatest = a # choose any variable (a, b, or c)

print('Testing condition #1')
if a > greatest:
    greatest = a

print('Testing condition #2')
if b > greatest:
    greatest = b

print('Testing condition #3')
if c > greatest:
    greatest = c

print(greatest)
# Out:
# Testing condition #1
# Testing condition #2
# Testing condition #3
# 3

# %% [markdown]
# But if the case your are testing for is mutually exclusive, you can use "elif" and "else" statements to test only the conditions that are necessary.

# %%
# Note: you'll have to comment-out the "Testing condition" messages for this cell to run
a = 1
b = 2
c = 3
greatest = a # choose any variable (a, b, or c)

print('Testing condition #1')
if a >= b and a >= c:
    greatest = a

print('Testing condition #2')
elif b >= a and b >= c:
    greatest = b

print('Testing condition #3')
else:
    greatest = c

print(greatest)
# Out:
# Testing condition #1
# 3

# %% [markdown]
# ### Functions can incorporate conditional statements

# %% [markdown]
# ### Conditional statements can be nested with indentation

# %% [markdown]
# # Final Exercise
# ---
# Let's make a "[Magic 8-Ball](https://en.wikipedia.org/wiki/Magic_8-Ball)" function
# * Your function will take a single string input
# * Your function will return a message based on the length of the string input
#     * Your function should return a minimum of six unique messages
#     * Use a combination of conditional statements and operators to determine the message output
#     * HINT: You can use the "len()" function to determine the length of the string input
# * Don't forget to add some documentation
#
# BONUS POINTS:
# * Check that the input is a string (and not something else like an integer or float)
# * Check that the input contains a question mark ("?")
# * If no input is provided, prompt the user for input (check out the "input()" function)
# * Add a conditional statement that checks for an exact string match and returns a unique message for that specific string input
# * Check that a single input was provided to the function
#
# MEGA BONUS POINTS:
# * Upload your magic 8-ball function to your GitHub and have a neighbor try it out!

# %%
# here's an example
def mikes_magic_8(x):
    """This is my magic 8 ball function
    
    Arguments
    _________
    x (string): the question
    
    Returns
    _______
    
    
    """
    if len(x) < 4:
        return "I'm gonna say no on this one"
    
    if x == "cheese?":
        return "Yes PLEASE!"

# %%
mikes_magic_8("cheese?")
# Out:
# 'Yes PLEASE!'

# %%
# your turn to write a function!
